# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
a=pd.read_csv('customers.csv')

# %%
a
# Out:
#       CustomerID  Gender  Age  Annual_Income  Spending_Score     Profession  \
# 0              1    Male   19          15000              39     Healthcare
# 1              2    Male   21          35000              81       Engineer
# 2              3  Female   20          86000               6       Engineer
# 3              4  Female   23          59000              77         Lawyer
# 4              5  Female   31          38000              40  Entertainment
# ...          ...     ...  ...            ...             ...            ...
# 1995        1996  Female   71         184387              40         Artist
# 1996        1997  Female   91          73158              32         Doctor
# 1997        1998    Male   87          90961              14     Healthcare
# 1998        1999    Male   77         182109               4      Executive
# 1999        2000    Male   90         110610              52  Entertainment
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         2000 non-null   int64
#  1   Gender             2000 non-null   object
#  2   Age                2000 non-null   int64
#  3   Annual_Income      2000 non-null   int64
#  4   Spending_Score     2000 non-null   int64
#  5   Profession         1965 non-null   object
#  6   Work_Experience    2000 non-null   int64
#  7   Family Size        2000 non-null   int64
#  8   Spending_Category  2000 non-null   object
#  9   Invoice_Number     2000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 156.4+ KB

# %%
d1=a.iloc[:11,::]

# %%
d1
# Out:
#     CustomerID  Gender  Age  Annual_Income  Spending_Score     Profession  \
# 0            1    Male   19          15000              39     Healthcare
# 1            2    Male   21          35000              81       Engineer
# 2            3  Female   20          86000               6       Engineer
# 3            4  Female   23          59000              77         Lawyer
# 4            5  Female   31          38000              40  Entertainment
# 5            6  Female   22          58000              76         Artist
# 6            7  Female   35          31000               6     Healthcare
# 7            8  Female   23          84000              94     Healthcare
# 8            9    Male   64          97000               3       Engineer
# 9           10  Female   30          98000              72         Artist
# 10          11    Male   67           7000              14       Engineer
#
#     Work_Experience  Family Size Spending_Category  Invoice_Number
# ...

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         11 non-null     int64
#  1   Gender             11 non-null     object
#  2   Age                11 non-null     int64
#  3   Annual_Income      11 non-null     int64
#  4   Spending_Score     11 non-null     int64
#  5   Profession         11 non-null     object
#  6   Work_Experience    11 non-null     int64
#  7   Family Size        11 non-null     int64
#  8   Spending_Category  11 non-null     object
#  9   Invoice_Number     11 non-null     int64
# dtypes: int64(7), object(3)
# memory usage: 1012.0+ bytes

# %%
#lineplot

# %%
plt.plot(d1['Spending_Category'],d1['Spending_Score'],'r*--',ms=10,mec='b',mfc='g')
plt.xlabel('Spending_Category')
plt.ylabel('Spending_Score')
plt.title('Spending_Category vs Spending_Score')
# Out:
# Text(0.5, 1.0, 'Spending_Category vs Spending_Score')

# %%
#Scatterplot

# %%
plt.scatter(d1['Age'],d1['Annual_Income'])
plt.xlabel('Age')
plt.ylabel('Annual_Income')
plt.title('Age vs Annual_Income')
# Out:
# Text(0.5, 1.0, 'Age vs Annual_Income')

# %%
#pie graph

# %%
d=d1.groupby('Profession').size()

# %%
d.index
# Out:
# Index(['Artist', 'Engineer', 'Entertainment', 'Healthcare', 'Lawyer'], dtype='object', name='Profession')

# %%
d.values
# Out:
# array([2, 4, 1, 3, 1], dtype=int64)

# %%
plt.pie(d.values,labels=d.index,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1605a479a60>,
# ...
#  [Text(0.9253788759906099, 0.5947049149539254, 'Artist'),
#   Text(-0.7203468639465174, 0.8313244827396927, 'Engineer'),
#   Text(-0.9253788203103135, -0.5947050015941457, 'Entertainment'),
#   Text(0.15654647964602333, -1.0888035634174043, 'Healthcare'),
#   Text(1.0554423263691122, -0.30990562387371495, 'Lawyer')],
#  [Text(0.5047521141766963, 0.32438449906577743, '18.18%'),
#   Text(-0.3929164712435549, 0.45344971785801413, '36.36%'),
#   Text(-0.5047520838056254, -0.3243845463240794, '9.09%'),
#   Text(0.08538898889783089, -0.5938928527731295, '27.27%'),
#   Text(0.5756958143831521, -0.1690394312038445, '9.09%')])

# %%
#bar graph

# %%
d2=a.groupby('Gender')['Annual_Income'].sum()

# %%
d2.index
# Out:
# Index(['Female', 'Male'], dtype='object', name='Gender')

# %%
d2.values
# Out:
# array([131116706,  90346937], dtype=int64)

# %%
plt.bar(d2.index,d2.values)
# Out:
# <BarContainer object of 2 artists>

# %%
#Countplot

# %%
a['Profession'].value_counts().index
# Out:
# Index(['Artist', 'Healthcare', 'Entertainment', 'Engineer', 'Doctor',
#        'Executive', 'Lawyer', 'Marketing', 'Homemaker'],
#       dtype='object', name='Profession')

# %%
sns.countplot(x=a['Profession'],order=a['Profession'].value_counts().index)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Artist'),
#   Text(1, 0, 'Healthcare'),
#   Text(2, 0, 'Entertainment'),
#   Text(3, 0, 'Engineer'),
#   Text(4, 0, 'Doctor'),
#   Text(5, 0, 'Executive'),
#   Text(6, 0, 'Lawyer'),
#   Text(7, 0, 'Marketing'),
#   Text(8, 0, 'Homemaker')])

# %%
#Correlation Matrix

# %%
d3=a[['CustomerID','Age','Annual_Income','Spending_Score','Work_Experience','Family Size']]

# %%
d3
# Out:
#       CustomerID  Age  Annual_Income  Spending_Score  Work_Experience  \
# 0              1   19          15000              39                1
# 1              2   21          35000              81                3
# 2              3   20          86000               6                1
# 3              4   23          59000              77                0
# 4              5   31          38000              40                2
# ...          ...  ...            ...             ...              ...
# 1995        1996   71         184387              40                8
# 1996        1997   91          73158              32                7
# 1997        1998   87          90961              14                9
# 1998        1999   77         182109               4                7
# 1999        2000   90         110610              52                5
#
#       Family Size
# 0               4
# 1               3
# 2               1
# 3               2
# 4               6
# ...

# %%
d3.corr()
# Out:
#                  CustomerID       Age  Annual_Income  Spending_Score  \
# CustomerID         1.000000  0.070700       0.328400        0.018936
# Age                0.070700  1.000000       0.021378       -0.041798
# Annual_Income      0.328400  0.021378       1.000000        0.023299
# Spending_Score     0.018936 -0.041798       0.023299        1.000000
# Work_Experience    0.091574 -0.014319       0.089136       -0.028948
# Family Size        0.159655  0.038254       0.093005        0.002232
#
#                  Work_Experience  Family Size
# CustomerID              0.091574     0.159655
# Age                    -0.014319     0.038254
# Annual_Income           0.089136     0.093005
# Spending_Score         -0.028948     0.002232
# Work_Experience         1.000000     0.011873
# Family Size             0.011873     1.000000

# %%
sns.heatmap(d3.corr(),annot=True)
# Out:
# <Axes: >

# %%
#scatter plot by seaborn

# %%
sns.scatterplot(x=d1['Age'],y=d1['Annual_Income'],hue=d1['Gender'])
# Out:
# <Axes: xlabel='Age', ylabel='Annual_Income'>

# %%
#histplot

# %%
sns.histplot(x=a['Spending_Score'],bins=10,kde=True)
# Out:
# <Axes: xlabel='Spending_Score', ylabel='Count'>

# %%
#displot

# %%
sns.displot(x=a['Spending_Score'],bins=10,kde=True)

# %%
#boxplot

# %%
sns.boxplot(data=a,x='Profession',y='Work_Experience')
# Out:
# <Axes: xlabel='Profession', ylabel='Work_Experience'>

# %%
#pairplot

# %%
sns.pairplot(d1,hue='Gender')

# %%
#strip plot

# %%
sns.stripplot(x=a['Spending_Category'],y=a['Spending_Score'],hue=a['Gender'],dodge=True)
# Out:
# <Axes: xlabel='Spending_Category', ylabel='Spending_Score'>
