# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('customers.csv')

# %%
r={'Low':0,'Average':1,'High':2}

# %%
df['Spending_Category']=df['Spending_Category'].map(r)

# %%
df
# Out:
#       CustomerID  Gender  Age  Annual_Income  Spending_Score     Profession  \
# 0              1    Male   19          15000              39     Healthcare
# 1              2    Male   21          35000              81       Engineer
# 2              3  Female   20          86000               6       Engineer
# 3              4  Female   23          59000              77         Lawyer
# 4              5  Female   31          38000              40  Entertainment
# ...          ...     ...  ...            ...             ...            ...
# 1995        1996  Female   71         184387              40         Artist
# 1996        1997  Female   91          73158              32         Doctor
# 1997        1998    Male   87          90961              14     Healthcare
# 1998        1999    Male   77         182109               4      Executive
# 1999        2000    Male   90         110610              52  Entertainment
#
#       Work_Experience  Family Size  Spending_Category  Invoice_Number
# 0                   1            4                  1          458984
# 1                   3            3                  2          458994
# 2                   1            1                  0          458994
# 3                   0            2                  2          458997
# 4                   2            6                  1          458999
# ...               ...          ...                ...             ...
# 1995                8            7                  1          461768
# 1996                7            7                  1          461773
# 1997                9            2                  0          461774
# 1998                7            2                  0          461775
# 1999                5            2                  2          461775
#
# [2000 rows x 10 columns]

# %%
df1 = df.drop(columns=["CustomerID", "Gender", "Profession", "Invoice_Number"])

# %%
X = df1.drop(["Spending_Category"],axis='columns')
y = df1["Spending_Category"]

# %%
X
# Out:
#       Age  Annual_Income  Spending_Score  Work_Experience  Family Size
# 0      19          15000              39                1            4
# 1      21          35000              81                3            3
# 2      20          86000               6                1            1
# 3      23          59000              77                0            2
# 4      31          38000              40                2            6
# ...   ...            ...             ...              ...          ...
# 1995   71         184387              40                8            7
# 1996   91          73158              32                7            7
# 1997   87          90961              14                9            2
# 1998   77         182109               4                7            2
# 1999   90         110610              52                5            2
#
# [2000 rows x 5 columns]

# %%
y
# Out:
# 0       1
# 1       2
# 2       0
# 3       2
# 4       1
#        ..
# 1995    1
# 1996    1
# 1997    0
# 1998    0
# 1999    2
# Name: Spending_Category, Length: 2000, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=2)

# %%
X_train.shape
# Out:
# (1998, 5)

# %%
X_test.shape
# Out:
# (2, 5)

# %%
X.shape
# Out:
# (2000, 5)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\Windows\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([2, 2], dtype=int64)

# %%
y_test
# Out:
# 13     2
# 639    2
# Name: Spending_Category, dtype: int64
